# %%
import sys
print(sys.argv)
# Out:
# ['C:\\Users\\mahir.er\\AppData\\Roaming\\Python\\Python311\\site-packages\\ipykernel_launcher.py', '--ip=127.0.0.1', '--stdin=9003', '--control=9001', '--hb=9000', '--Session.signature_scheme="hmac-sha256"', '--Session.key=b"d2d377e2-1f5c-44ac-8e47-2291d8e6be0f"', '--shell=9002', '--transport="tcp"', '--iopub=9004', '--f=c:\\Users\\mahir.er\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-7248XjNQ5Q1r8Yw7.json']
